# %% [markdown]
# ## Install required R packages

# %%
# R script
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
BiocManager::install("ggbio")
BiocManager::install("biovizBase")

install.packages(c("data.table","Signac", "tidyverse", "argparse"))

BiocManager::install(c("ensembldb", "EnsDb.Mmusculus.v79", "EnsDb.Hsapiens.v86","GenomicRanges"))

# %%
# R script
sessionInfo()

# %% [raw]
# R version 4.0.4 (2021-02-15)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 20.04.1 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.9.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.9.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
# [1] compiler_4.0.4 tools_4.0.4

# %%
# R script to check version of installed packages
ip = as.data.frame(installed.packages()[,c(1,3:4)])
ip = ip[is.na(ip$Priority),1:2,drop=FALSE]
ip

# %% [raw]
#                                   Package     Version
# AnnotationFilter         AnnotationFilter      1.14.0
# argparse                         argparse       2.0.3
# arrow                               arrow       4.0.0
# AUCell                             AUCell      1.13.3
# beachmat                         beachmat       2.6.4
# BH                                     BH    1.75.0-0
# BiocGenerics                 BiocGenerics      0.36.1
# BiocNeighbors               BiocNeighbors       1.8.2
# biovizBase                     biovizBase      1.38.0
# bmp                                   bmp         0.3
# bowerbird                       bowerbird       0.0.2
# brio                                 brio       1.1.2
# broom                               broom       0.7.6
# BSgenome                         BSgenome      1.58.0
# Cairo                               Cairo    1.5-12.2
# CellChat                         CellChat       1.1.2
# circlize                         circlize 0.4.13.1001
# cisTopic                         cisTopic       0.3.0
# cli                                   cli       2.5.0
# clue                                 clue      0.3-58
# colorspace                     colorspace       2.0-1
# ComplexHeatmap             ComplexHeatmap  2.7.8.1000
# cpp11                               cpp11       0.2.7
# crayon                             crayon       1.4.1
# curl                                 curl       4.3.1
# data.table                     data.table      1.14.0
# dbplyr                             dbplyr       2.1.1
# DelayedArray                 DelayedArray      0.16.1
# devtools                         devtools       2.4.2
# dichromat                       dichromat       2.0-0
# diffobj                           diffobj       0.3.4
# doSNOW                             doSNOW      1.0.19
# downloader                     downloader         0.4
# dplyr                               dplyr       1.0.4
# dtplyr                             dtplyr       1.1.0
# edgeR                               edgeR      3.32.1
# EnsDb.Hsapiens.v75     EnsDb.Hsapiens.v75      2.99.0
# EnsDb.Hsapiens.v86     EnsDb.Hsapiens.v86      2.99.0
# EnsDb.Mmusculus.v79   EnsDb.Mmusculus.v79      2.99.0
# ensembldb                       ensembldb      2.14.1
# fansi                               fansi       0.5.0
# fastmatch                       fastmatch       1.1-0
# fgsea                               fgsea      1.16.0
# findpython                     findpython       1.0.7
# float                               float       0.2-4
# GenomeInfoDb                 GenomeInfoDb      1.26.2
# GenomicRanges               GenomicRanges      1.42.0
# GetoptLong                     GetoptLong       1.0.5
# gg.gap                             gg.gap         1.3
# ggalluvial                     ggalluvial      0.12.3
# GGally                             GGally       2.1.1
# ggbio                               ggbio      1.38.0
# ggforce                           ggforce       0.3.2
# ggplot2                           ggplot2       3.3.3
# ggraph                             ggraph       2.0.4
# ggrepel                           ggrepel       0.9.1
# ggseqlogo                       ggseqlogo         0.1
# GlobalOptions               GlobalOptions       0.1.2
# googledrive                   googledrive       1.0.1
# googlesheets4               googlesheets4       0.3.0
# graph                               graph      1.68.0
# graphlayouts                 graphlayouts       0.7.1
# gridBase                         gridBase       0.4-7
# GSEABase                         GSEABase      1.52.1
# ids                                   ids       1.0.1
# imager                             imager     0.42.10
# IRanges                           IRanges      2.24.1
# isoband                           isoband       0.2.4
# jsonlite                         jsonlite       1.7.2
# ktplots                           ktplots      1.1.14
# lda                                   lda       1.4.2
# lgr                                   lgr       0.4.2
# MatrixGenerics             MatrixGenerics       1.2.1
# matrixStats                   matrixStats      0.58.0
# Metrics                           Metrics       0.1.4
# miloR                               miloR      0.99.1
# mlapi                               mlapi       0.1.0
# network                           network      1.16.1
# NMF                                   NMF      0.23.0
# openssl                           openssl       1.4.4
# OrganismDbi                   OrganismDbi      1.32.0
# patchwork                       patchwork       1.1.1
# pillar                             pillar       1.6.0
# pkgbuild                         pkgbuild       1.2.0
# pkgload                           pkgload       1.2.1
# pkgmaker                         pkgmaker      0.32.2
# processx                         processx       3.4.5
# ProtGenerics                 ProtGenerics      1.22.0
# ps                                     ps       1.6.0
# RBGL                                 RBGL      1.66.0
# RcisTarget                     RcisTarget     1.11.10
# Rcpp                                 Rcpp       1.0.6
# RcppArmadillo               RcppArmadillo  0.10.5.0.0
# RcppEigen                       RcppEigen   0.3.3.9.1
# RcppRoll                         RcppRoll       0.3.0
# readbitmap                     readbitmap       0.1.5
# registry                         registry       0.5-1
# remotes                           remotes       2.4.0
# reprex                             reprex       2.0.0
# reshape                           reshape       0.8.8
# rlang                               rlang      0.4.11
# rle                                   rle       0.9.2
# rlist                               rlist     0.4.6.1
# rsparse                           rsparse       0.4.0
# s2                                     s2       1.0.6
# S4Vectors                       S4Vectors      0.28.1
# SeuratDisk                     SeuratDisk  0.0.0.9019
# Signac                             Signac       1.1.1
# sna                                   sna         2.6
# statnet.common             statnet.common       4.4.1
# stringi                           stringi       1.6.2
# superml                           superml       0.5.3
# testthat                         testthat       3.0.1
# text2vec                         text2vec         0.6
# textrank                         textrank       0.3.1
# tibble                             tibble       3.0.6
# tidygraph                       tidygraph       1.2.0
# tidyverse                       tidyverse       1.3.1
# tiff                                 tiff       0.1-8
# tvR                                   tvR       0.3.1
# tweenr                             tweenr       1.0.1
# udpipe                             udpipe       0.8.6
# VariantAnnotation       VariantAnnotation      1.36.0
# vctrs                               vctrs       0.3.6
# viridisLite                   viridisLite       0.4.0
# withr                               withr       2.4.2
# wk                                     wk       0.5.0
# xfun                                 xfun        0.23
# zip                                   zip       2.2.0
# abind                               abind       1.4-5
# ade4                                 ade4      1.7-16
# annotate                         annotate      1.68.0
# AnnotationDbi               AnnotationDbi      1.52.0
# ape                                   ape       5.4-1
# aroma.light                   aroma.light      3.20.0
# askpass                           askpass         1.1
# assertthat                     assertthat       0.2.1
# backports                       backports       1.2.1
# base64enc                       base64enc       0.1-3
# batchelor                       batchelor       1.6.2
# bbmle                               bbmle    1.0.23.1
# bdsmatrix                       bdsmatrix       1.3-4
# beachmat.1                       beachmat       2.6.4
# beeswarm                         beeswarm       0.3.1
# BH.1                                   BH    1.75.0-0
# Biobase                           Biobase      2.50.0
# BiocFileCache               BiocFileCache      1.14.0
# BiocGenerics.1               BiocGenerics      0.36.0
# BiocManager                   BiocManager     1.30.10
# BiocNeighbors.1             BiocNeighbors       1.8.2
# BiocParallel                 BiocParallel      1.24.1
# BiocSingular                 BiocSingular       1.6.0
# BiocVersion                   BiocVersion      3.12.0
# biomaRt                           biomaRt      2.46.3
# Biostrings                     Biostrings      2.58.0
# bit                                   bit       4.0.4
# bit64                               bit64       4.0.5
# bitops                             bitops       1.0-6
# blob                                 blob       1.2.1
# bluster                           bluster       1.0.0
# brew                                 brew       1.0-6
# brio.1                               brio       1.1.1
# broom.1                             broom       0.7.5
# bslib                               bslib       0.2.4
# cachem                             cachem       1.0.4
# callr                               callr       3.5.1
# car                                   car      3.0-10
# carData                           carData       3.0-4
# caTools                           caTools      1.18.1
# cellranger                     cellranger       1.1.0
# changepoint                   changepoint       2.2.2
# checkmate                       checkmate       2.0.0
# classInt                         classInt       0.4-3
# cli.1                                 cli       2.3.1
# clipr                               clipr       0.7.1
# clisymbols                     clisymbols       1.2.0
# coda                                 coda      0.19-4
# colorspace.1                   colorspace       2.0-0
# commonmark                     commonmark         1.7
# conquer                           conquer       1.0.2
# corrplot                         corrplot        0.84
# covr                                 covr       3.5.1
# cowplot                           cowplot       1.1.1
# cpp11.1                             cpp11       0.2.6
# crayon.1                           crayon       1.4.1
# credentials                   credentials       1.3.0
# crosstalk                       crosstalk       1.1.1
# curl.1                               curl         4.3
# cyclocomp                       cyclocomp       1.1.0
# data.table.1                   data.table      1.14.0
# DBI                                   DBI       1.1.1
# dbplyr.1                           dbplyr       2.1.0
# DelayedArray.1               DelayedArray      0.16.3
# DelayedMatrixStats     DelayedMatrixStats      1.12.3
# deldir                             deldir      0.2-10
# DEoptimR                         DEoptimR       1.0-8
# desc                                 desc       1.3.0
# DESeq2                             DESeq2      1.30.1
# destiny                           destiny       3.4.0
# devtools.1                       devtools       2.3.2
# diffobj.1                         diffobj       0.3.4
# digest                             digest      0.6.27
# dlm                                   dlm       1.1-5
# dndscv                             dndscv     0.0.1.0
# doParallel                     doParallel      1.0.16
# doRNG                               doRNG       1.8.2
# downlit                           downlit       0.2.1
# dplyr.1                             dplyr       1.0.5
# dqrng                               dqrng       0.2.1
# DropletUtils                 DropletUtils      1.10.3
# DT                                     DT        0.17
# e1071                               e1071       1.7-6
# EDASeq                             EDASeq      2.24.0
# edgeR.1                             edgeR      3.32.1
# ellipsis                         ellipsis       0.3.1
# enrichR                           enrichR         3.0
# evaluate                         evaluate        0.14
# expm                                 expm     0.999-6
# fansi.1                             fansi       0.4.2
# farver                             farver       2.1.0
# fastICA                           fastICA       1.2-2
# fastmap                           fastmap       1.1.0
# fBasics                           fBasics   3042.89.1
# feather                           feather       0.3.5
# fGarch                             fGarch   3042.83.2
# fitdistrplus                 fitdistrplus       1.1-3
# FNN                                   FNN       1.1.3
# foghorn                           foghorn       1.3.2
# fontBitstreamVera       fontBitstreamVera       0.1.1
# fontLiberation             fontLiberation       0.1.0
# fontquiver                     fontquiver       0.2.1
# forcats                           forcats       0.5.1
# foreach                           foreach       1.5.1
# forecast                         forecast        8.14
# formatR                           formatR         1.8
# Formula                           Formula       1.2-4
# fracdiff                         fracdiff       1.5-1
# freetypeharfbuzz         freetypeharfbuzz       0.2.6
# fs                                     fs       1.5.0
# furrr                               furrr       0.2.2
# futile.logger               futile.logger       1.4.3
# futile.options             futile.options       1.0.1
# future                             future      1.21.0
# future.apply                 future.apply       1.7.0
# gargle                             gargle       1.0.0
# gdata                               gdata      2.18.0
# gdtools                           gdtools       0.2.3
# genefilter                     genefilter      1.72.1
# geneplotter                   geneplotter      1.68.0
# generics                         generics       0.1.0
# GenomeInfoDb.1               GenomeInfoDb      1.26.4
# GenomeInfoDbData         GenomeInfoDbData       1.2.4
# GenomicAlignments       GenomicAlignments      1.26.0
# GenomicFeatures           GenomicFeatures      1.42.2
# GenomicRanges.1             GenomicRanges      1.42.0
# gert                                 gert       1.2.0
# getopt                             getopt      1.20.3
# ggbeeswarm                     ggbeeswarm       0.6.0
# ggfortify                       ggfortify      0.4.11
# ggplot.multistats       ggplot.multistats       1.0.0
# ggplot2.1                         ggplot2       3.3.3
# ggplot2movies               ggplot2movies       0.0.1
# ggpubr                             ggpubr       0.4.0
# ggrepel.1                         ggrepel       0.9.1
# ggridges                         ggridges       0.5.3
# ggsci                               ggsci         2.9
# ggsignif                         ggsignif       0.6.1
# ggthemes                         ggthemes       4.2.4
# gh                                     gh       1.2.0
# gitcreds                         gitcreds       0.1.1
# glmnet                             glmnet       4.1-1
# globals                           globals      0.14.0
# glue                                 glue       1.4.2
# gmailr                             gmailr       1.0.0
# gmodels                           gmodels      2.18.1
# goftest                           goftest       1.2-2
# gplots                             gplots       3.1.1
# gridExtra                       gridExtra         2.3
# grr                                   grr       0.9.5
# gss                                   gss       2.2-2
# gtable                             gtable       0.3.0
# gtools                             gtools       3.8.2
# harmony                           harmony         1.0
# haven                               haven       2.3.1
# HDF5Array                       HDF5Array      1.18.1
# hdf5r                               hdf5r       1.3.3
# hexbin                             hexbin      1.28.2
# highr                               highr         0.8
# Hmisc                               Hmisc       4.5-0
# hms                                   hms       1.0.0
# htmlTable                       htmlTable       2.1.0
# htmltools                       htmltools     0.5.1.1
# htmlwidgets                   htmlwidgets       1.5.3
# httpuv                             httpuv       1.5.5
# httr                                 httr       1.4.2
# hunspell                         hunspell       3.0.1
# hwriter                           hwriter       1.3.2
# ica                                   ica       1.0-2
# igraph                             igraph       1.2.6
# igraphdata                     igraphdata       1.0.1
# ini                                   ini       0.3.1
# IRanges.1                         IRanges      2.24.1
# IRdisplay                       IRdisplay         1.0
# IRkernel                         IRkernel       1.1.1
# irlba                               irlba       2.3.3
# isoband.1                         isoband       0.2.4
# iterators                       iterators      1.0.13
# itertools                       itertools       0.1-3
# jpeg                                 jpeg     0.1-8.1
# jquerylib                       jquerylib       0.1.3
# jsonlite.1                       jsonlite       1.7.2
# kernlab                           kernlab      0.9-29
# KFAS                                 KFAS       1.4.4
# knitr                               knitr        1.31
# knn.covertree               knn.covertree         1.0
# labeling                         labeling       0.4.2
# laeken                             laeken       0.5.1
# lambda.r                         lambda.r       1.2.4
# later                               later     1.1.0.1
# latticeExtra                 latticeExtra      0.6-29
# lazyeval                         lazyeval       0.2.2
# LearnBayes                     LearnBayes      2.15.1
# leiden                             leiden       0.3.7
# leidenbase                     leidenbase       0.1.2
# lfda                                 lfda       1.1.3
# lifecycle                       lifecycle       1.0.0
# limma                               limma      3.46.0
# lintr                               lintr       2.0.1
# listenv                           listenv       0.8.0
# lme4                                 lme4      1.1-26
# lmtest                             lmtest      0.9-38
# locfit                             locfit     1.5-9.4
# LoomExperiment             LoomExperiment       1.8.0
# loomR                               loomR       0.2.0
# lsa                                   lsa      0.73.2
# lubridate                       lubridate      1.7.10
# M3Drop                             M3Drop      1.16.0
# magrittr                         magrittr       2.0.1
# manipulateWidget         manipulateWidget      0.10.1
# mapdata                           mapdata       2.3.0
# mapproj                           mapproj       1.2.7
# maps                                 maps       3.3.0
# maptools                         maptools       1.1-1
# markdown                         markdown         1.1
# mathjaxr                         mathjaxr       1.4-0
# Matrix.utils                 Matrix.utils       0.9.8
# MatrixGenerics.1           MatrixGenerics       1.2.1
# MatrixModels                 MatrixModels       0.5-0
# matrixStats.1                 matrixStats      0.58.0
# memoise                           memoise       2.0.0
# memuse                             memuse       4.1-0
# mime                                 mime        0.10
# miniUI                             miniUI     0.1.1.1
# minqa                               minqa       1.2.4
# mixtools                         mixtools       1.2.0
# mnormt                             mnormt       2.0.2
# mockery                           mockery       0.4.2
# modelr                             modelr       0.1.8
# monocle3                         monocle3     0.2.3.0
# MSwM                                 MSwM         1.4
# multcomp                         multcomp      1.4-16
# MultiAssayExperiment MultiAssayExperiment      1.16.0
# munsell                           munsell       0.5.0
# mvtnorm                           mvtnorm       1.1-1
# nloptr                             nloptr     1.2.2.2
# NLP                                   NLP       0.2-1
# numDeriv                         numDeriv  2016.8-1.1
# openssl.1                         openssl       1.4.3
# openxlsx                         openxlsx       4.2.3
# optparse                         optparse       1.6.6
# parallelly                     parallelly      1.24.0
# parsedate                       parsedate       1.2.0
# patchwork.1                     patchwork       1.1.1
# pbapply                           pbapply       1.4-3
# pbdZMQ                             pbdZMQ       0.3-5
# pbkrtest                         pbkrtest       0.5.1
# pbmcapply                       pbmcapply       1.5.0
# pcaMethods                     pcaMethods      1.82.0
# pcaPP                               pcaPP      1.9-73
# permute                           permute       0.9-5
# phateR                             phateR       1.0.7
# pheatmap                         pheatmap      1.0.12
# pillar.1                           pillar       1.5.1
# pinfsc50                         pinfsc50       1.2.0
# pingr                               pingr       2.0.1
# pixmap                             pixmap      0.4-12
# pkgbuild.1                       pkgbuild       1.2.0
# pkgconfig                       pkgconfig       2.0.3
# pkgdown                           pkgdown       1.6.1
# pkgload.1                         pkgload       1.2.0
# plogr                               plogr       0.2.0
# plotly                             plotly       4.9.3
# plotrix                           plotrix       3.8-1
# plyr                                 plyr       1.8.6
# png                                   png       0.1-7
# poilog                             poilog         0.4
# polyclip                         polyclip      1.10-0
# polynom                           polynom       1.4-0
# praise                             praise       1.0.0
# prettyunits                   prettyunits       1.1.1
# processx.1                       processx       3.5.0
# profvis                           profvis       0.3.7
# progress                         progress       1.2.2
# promises                         promises     1.2.0.1
# proxy                               proxy      0.4-25
# ps.1                                   ps       1.6.0
# pscl                                 pscl       1.5.5
# purrr                               purrr       0.3.4
# quadprog                         quadprog       1.5-8
# quantmod                         quantmod      0.4.18
# quantreg                         quantreg        5.85
# R.methodsS3                   R.methodsS3       1.8.1
# R.oo                                 R.oo      1.24.0
# R.utils                           R.utils      2.10.1
# R6                                     R6       2.5.0
# ragg                                 ragg       1.1.2
# ranger                             ranger      0.12.1
# RANN                                 RANN       2.6.1
# rappdirs                         rappdirs       0.3.3
# rARPACK                           rARPACK      0.11-0
# raster                             raster       3.4-5
# rbibutils                       rbibutils         2.0
# rcmdcheck                       rcmdcheck       1.3.3
# RColorBrewer                 RColorBrewer       1.1-2
# Rcpp.1                               Rcpp       1.0.6
# RcppAnnoy                       RcppAnnoy      0.0.18
# RcppArmadillo.1             RcppArmadillo  0.10.2.2.0
# RcppEigen.1                     RcppEigen   0.3.3.9.1
# RcppGSL                           RcppGSL       0.3.8
# RcppHNSW                         RcppHNSW       0.3.0
# RcppProgress                 RcppProgress       0.4.2
# RcppZiggurat                 RcppZiggurat       0.1.6
# RCurl                               RCurl    1.98-1.3
# Rdpack                             Rdpack       2.1.1
# readr                               readr       1.4.0
# readxl                             readxl       1.3.1
# reldist                           reldist       1.6-6
# rematch                           rematch       1.0.1
# rematch2                         rematch2       2.1.2
# remotes.1                         remotes       2.2.0
# repr                                 repr       1.1.3
# reprex.1                           reprex       1.0.0
# reshape2                         reshape2       1.4.4
# ResidualMatrix             ResidualMatrix       1.0.0
# reticulate                     reticulate        1.18
# rex                                   rex       1.2.0
# Rfast                               Rfast       2.0.1
# Rfast2                             Rfast2       0.0.9
# rgeos                               rgeos       0.5-5
# rgl                                   rgl    0.105.22
# rhdf5                               rhdf5      2.34.0
# rhdf5filters                 rhdf5filters       1.2.0
# Rhdf5lib                         Rhdf5lib      1.12.1
# RhpcBLASctl                   RhpcBLASctl    0.20-137
# Rhtslib                           Rhtslib      1.22.0
# rhub                                 rhub       1.1.1
# rio                                   rio      0.5.26
# rjson                               rjson      0.2.20
# rlang.1                             rlang      0.4.10
# Rmagic                             Rmagic       2.0.3
# rmarkdown                       rmarkdown         2.7
# rngtools                         rngtools         1.5
# robustbase                     robustbase      0.93-7
# ROCR                                 ROCR      1.0-11
# roxygen2                         roxygen2       7.1.1
# rprojroot                       rprojroot       2.0.2
# rrcov                               rrcov       1.5-5
# rsample                           rsample       0.0.9
# Rsamtools                       Rsamtools       2.6.0
# RSpectra                         RSpectra      0.16-0
# RSQLite                           RSQLite       2.2.4
# rstatix                           rstatix       0.7.0
# rstudioapi                     rstudioapi        0.13
# rsvd                                 rsvd       1.0.3
# rtracklayer                   rtracklayer      1.50.0
# Rtsne                               Rtsne        0.15
# RUVSeq                             RUVSeq      1.24.0
# rversions                       rversions       2.0.2
# rvest                               rvest       1.0.0
# S4Vectors.1                     S4Vectors      0.28.1
# sandwich                         sandwich       3.0-0
# sass                                 sass       0.3.1
# SC3                                   SC3      1.18.0
# scales                             scales       1.1.1
# scater                             scater      1.18.6
# scattermore                   scattermore         0.7
# scatterplot3d               scatterplot3d      0.3-41
# sceasy                             sceasy       0.0.6
# scran                               scran      1.18.5
# sctransform                   sctransform       0.3.2
# scuttle                           scuttle       1.0.4
# segmented                       segmented       1.3-3
# selectr                           selectr       0.4-2
# seqinr                             seqinr       4.2-5
# sessioninfo                   sessioninfo       1.1.1
# Seurat                             Seurat       4.0.1
# SeuratObject                 SeuratObject       4.0.0
# sf                                     sf       0.9-8
# shape                               shape       1.4.5
# shiny                               shiny       1.6.0
# ShortRead                       ShortRead      1.48.0
# SingleCellExperiment SingleCellExperiment      1.12.0
# sitmo                               sitmo       2.0.1
# slam                                 slam      0.1-48
# slider                             slider       0.2.1
# smoother                         smoother         1.1
# sn                                     sn       1.6-2
# snow                                 snow       0.4-3
# SnowballC                       SnowballC       0.7.0
# softImpute                     softImpute         1.4
# SoupX                               SoupX       1.5.0
# sourcetools                   sourcetools       0.1.7
# sp                                     sp       1.4-5
# SparseM                           SparseM        1.81
# sparseMatrixStats       sparseMatrixStats       1.2.1
# spatstat.core               spatstat.core       2.0-0
# spatstat.data               spatstat.data       2.1-0
# spatstat.geom               spatstat.geom       2.0-1
# spatstat.sparse           spatstat.sparse       2.0-0
# spatstat.utils             spatstat.utils       2.1-0
# spData                             spData       0.3.8
# spdep                               spdep       1.1-5
# speedglm                         speedglm       0.3-3
# spelling                         spelling         2.2
# stabledist                     stabledist       0.7-1
# statmod                           statmod      1.4.35
# stringi.1                         stringi       1.5.3
# stringr                           stringr       1.4.0
# strucchange                   strucchange       1.5-2
# SummarizedExperiment SummarizedExperiment      1.20.0
# sva                                   sva      3.38.0
# svglite                           svglite       2.0.0
# switchde                         switchde      1.16.0
# sys                                   sys         3.4
# systemfonts                   systemfonts       1.0.1
# tensor                             tensor         1.5
# testthat.1                       testthat       3.0.2
# textshaping                   textshaping       0.3.3
# TFisher                           TFisher       0.2.0
# TH.data                           TH.data      1.0-10
# tibble.1                           tibble       3.1.0
# tidyr                               tidyr       1.1.3
# tidyselect                     tidyselect       1.1.0
# tidyverse.1                     tidyverse       1.3.0
# timeDate                         timeDate    3043.102
# timeSeries                     timeSeries    3062.100
# tinytex                           tinytex        0.30
# tm                                     tm       0.7-8
# tmvnsim                           tmvnsim       1.0-2
# tseries                           tseries     0.10-48
# TTR                                   TTR      0.24.2
# umap                                 umap     0.2.7.0
# units                               units       0.7-1
# urca                                 urca       1.3-0
# usethis                           usethis       2.0.1
# utf8                                 utf8       1.2.1
# uuid                                 uuid       0.1-4
# uwot                                 uwot      0.1.10
# vars                                 vars       1.5-3
# vcd                                   vcd       1.4-8
# vcfR                                 vcfR      1.12.0
# vctrs.1                             vctrs       0.3.6
# vdiffr                             vdiffr       0.3.3
# vegan                               vegan       2.5-7
# velocyto.R                     velocyto.R         0.6
# VGAM                                 VGAM       1.1-5
# VIM                                   VIM       6.1.0
# vipor                               vipor       0.4.5
# viridis                           viridis       0.5.1
# viridisLite.1                 viridisLite       0.3.0
# waldo                               waldo       0.2.5
# warp                                 warp       0.2.0
# webshot                           webshot       0.5.2
# whisker                           whisker         0.4
# whoami                             whoami       1.3.0
# withr.1                             withr       2.4.1
# WriteXLS                         WriteXLS       6.2.0
# xfun.1                               xfun        0.22
# XML                                   XML    3.99-0.6
# xml2                                 xml2       1.3.2
# xmlparsedata                 xmlparsedata       1.0.5
# xopen                               xopen       1.0.0
# xtable                             xtable       1.8-4
# xts                                   xts      0.12.1
# XVector                           XVector      0.30.0
# yaml                                 yaml       2.2.1
# zinbwave                         zinbwave      1.12.0
# zip.1                                 zip       2.1.1
# zlibbioc                         zlibbioc      1.36.0
# zoo                                   zoo       1.8-9

# %% [markdown]
# ## Excute the Rscript after setup paths for each data

# %%
# Shell script
cellatac_outs=/nfs/team205/kk18/data/cellatac/tic-1050/results200k/peak_matrix
outdir=/nfs/team205/kk18/data/6region_v2/ATAC
Rscript /nfs/team205/kk18/data/6region_v2/ATAC/annotate_peaks.R \
$cellatac_outs/peaks.txt \
$outdir \
--genome hg38

# %% [raw]
# System has not been booted with systemd as init system (PID 1). Can't operate.
# Failed to create bus connection: Host is down
# Warning message:
# In system("timedatectl", intern = TRUE) :
#   running command 'timedatectl' had status 1
# Warning message:
# In valid.GenomicRanges.seqinfo(x, suggest.trim = TRUE) :
#   GRanges object contains 1 out-of-bound range located on sequence chrM.
#   Note that ranges located on a sequence whose length is unknown (NA) or
#   on a circular sequence are not considered out-of-bound (use
#   seqlengths() and isCircular() to get the lengths and circularity flags
#   of the underlying sequences). You can use trim() to trim these ranges.
#   See ?`trim,GenomicRanges-method` for more information.

# %%
# !ls /nfs/team205/kk18/data/6region_v2/ATAC
# Out:
# annotate_peaks.R  ATACpeaks_annotation.csv
