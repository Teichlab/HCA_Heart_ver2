# %%
library(ArchR)
library(tidyverse)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
# ...

# %%
# Prepare input files
metadata = read.csv('/nfs/team205/heart/anndata_objects/8regions/metadata/HeartTeamSamples_Mappeddata_20221208.csv')
metadata = metadata %>% filter(Publication %in% c('8regions','8regions_revision'))
metadata = metadata %>% filter(modality=='Multiome-ATAC')
nrow(metadata)

inputFiles = paste0(metadata %>% pull('Mapping_farm'),'/atac_fragments.tsv.gz')
names(inputFiles) = metadata %>% pull('CombinedID_Multiome')
inputFiles
# Out:
# [1] 47
#                                                                              HCAHeart9508627_HCAHeart9508819
# "/nfs/team205/heart/mapped/cellranger-arc200/remapped/HCAHeart9508627_HCAHeart9508819/atac_fragments.tsv.gz"
#                                                                              HCAHeart9508628_HCAHeart9508820
# "/nfs/team205/heart/mapped/cellranger-arc200/remapped/HCAHeart9508628_HCAHeart9508820/atac_fragments.tsv.gz"
#                                                                              HCAHeart9508629_HCAHeart9508821
# "/nfs/team205/heart/mapped/cellranger-arc200/remapped/HCAHeart9508629_HCAHeart9508821/atac_fragments.tsv.gz"
#                                                                              HCAHeart9845431_HCAHeart9917173
# "/nfs/team205/heart/mapped/cellranger-arc200/remapped/HCAHeart9845431_HCAHeart9917173/atac_fragments.tsv.gz"
# ...

# %%
names(inputFiles)
# Out:
#  [1] "HCAHeart9508627_HCAHeart9508819"
#  [2] "HCAHeart9508628_HCAHeart9508820"
#  [3] "HCAHeart9508629_HCAHeart9508821"
#  [4] "HCAHeart9845431_HCAHeart9917173"
#  [5] "HCAHeart9845432_HCAHeart9917174"
#  [6] "HCAHeart9845433_HCAHeart9917175"
#  [7] "HCAHeart9845434_HCAHeart9917176"
#  [8] "HCAHeart9845435_HCAHeart9917177"
#  [9] "HCAHeart9845436_HCAHeart9917178"
# [10] "HCAHeartST10773165_HCAHeartST10781062"
# [11] "HCAHeartST10773166_HCAHeartST10781063"
# [12] "HCAHeartST10773167_HCAHeartST10781064"
# [13] "HCAHeartST10773168_HCAHeartST10781065"
# [14] "HCAHeartST10773169_HCAHeartST10781446"
# [15] "HCAHeartST10773170_HCAHeartST10781447"
# [16] "HCAHeartST10773171_HCAHeartST10781448"
# [17] "HCAHeartST11064574_HCAHeartST11023239"
# [18] "HCAHeartST11064575_HCAHeartST11023240"
# [19] "HCAHeartST11064576_HCAHeartST11023241"
# [20] "HCAHeartST11064577_HCAHeartST11023242"
# [21] "HCAHeartST11350184_HCAHeartST11121842"
# [22] "HCAHeartST11350186_HCAHeartST11121844"
# ...

# %%
# before starting a project we must set the ArchRGenome and default threads for parallelization.
# Setting default genome to Hg38.
addArchRGenome("hg38")
# Out:
# Setting default genome to Hg38.

# %%
# Setting default number of Parallel threads to 16
addArchRThreads(threads = 10)
# Out:
# Setting default number of Parallel threads to 10.

# %%
getwd()
# Out:
# [1] "/nfs/team205/heart/anndata_objects/8regions/ArchR"

# %% [markdown]
# ## Creat Arrow files

# %%
ArrowFiles <- createArrowFiles(
  inputFiles = inputFiles,
  sampleNames = names(inputFiles),
  minTSS = 4, #Dont set this too high because you can always increase later
  minFrags = 1000, 
  addTileMat = TRUE,
  addGeneScoreMat = TRUE,
    force = TRUE
)
# Out:
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# Using GeneAnnotation set by addArchRGenome(Hg38)!
#
# ArchR logging to : ArchRLogs/ArchR-createArrows-44f84c0ce9cf-Date-2022-12-08_Time-18-35-46.log
# If there is an issue, please report to github with logFile!
#
# Cleaning Temporary Files
#
# 2022-12-08 18:35:46 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-createArrows-44f84c0ce9cf-Date-2022-12-08_Time-18-35-46.log

# %%
getwd()
# Out:
# [1] "/nfs/team205/heart/anndata_objects/8regions/ArchR"
