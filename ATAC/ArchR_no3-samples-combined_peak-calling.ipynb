# %% [markdown]
# Ref:
# https://www.archrproject.com/bookdown/creating-an-archrproject-1.html

# %%
library(ArchR)
library(tidyverse)
library(BSgenome.Hsapiens.UCSC.hg38)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
#
#
# ArchR : Version 1.0.2
# For more information see our website : www.ArchRProject.com
# If you encounter a bug please report : https://github.com/GreenleafLab/ArchR/issues
#
# Loading Required Packages...
#
# 	Loading Package : grid v4.0.4
#
# 	Loading Package : gridExtra v2.3
#
# 	Loading Package : gtools v3.9.3
#
# 	Loading Package : gtable v0.3.0
#
# 	Loading Package : ggplot2 v3.4.0
#
# 	Loading Package : magrittr v2.0.3
#
# 	Loading Package : plyr v1.8.8
#
# 	Loading Package : stringr v1.4.0
#
# 	Loading Package : data.table v1.14.4
#
# 	Loading Package : matrixStats v0.62.0
#
# 	Loading Package : S4Vectors v0.28.1
#
# 	Loading Package : GenomicRanges v1.42.0
#
# 	Loading Package : BiocGenerics v0.36.1
#
# 	Loading Package : Matrix v1.3.2
#
# 	Loading Package : Rcpp v1.0.9
#
# 	Loading Package : SummarizedExperiment v1.20.0
#
# 	Loading Package : rhdf5 v2.34.0
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8      ✔ purrr   0.3.4
# ✔ tidyr   1.2.1      ✔ dplyr   1.0.10
# ✔ readr   2.1.3      ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::arrange()         masks plyr::arrange()
# ✖ dplyr::between()         masks data.table::between()
# ✖ dplyr::collapse()        masks IRanges::collapse()
# ✖ dplyr::combine()         masks Biobase::combine(), BiocGenerics::combine(), gridExtra::combine()
# ✖ purrr::compact()         masks plyr::compact()
# ✖ dplyr::count()           masks matrixStats::count(), plyr::count()
# ✖ dplyr::desc()            masks IRanges::desc(), plyr::desc()
# ✖ tidyr::expand()          masks Matrix::expand(), S4Vectors::expand()
# ✖ tidyr::extract()         masks magrittr::extract()
# ✖ dplyr::failwith()        masks plyr::failwith()
# ✖ dplyr::filter()          masks stats::filter()
# ✖ dplyr::first()           masks S4Vectors::first(), data.table::first()
# ✖ dplyr::id()              masks plyr::id()
# ✖ dplyr::lag()             masks stats::lag()
# ✖ dplyr::last()            masks data.table::last()
# ✖ dplyr::mutate()          masks plyr::mutate()
# ✖ tidyr::pack()            masks Matrix::pack()
# ✖ BiocGenerics::Position() masks ggplot2::Position(), base::Position()
# ✖ purrr::reduce()          masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ dplyr::rename()          masks S4Vectors::rename(), plyr::rename()
# ✖ purrr::set_names()       masks magrittr::set_names()
# ✖ dplyr::slice()           masks IRanges::slice()
# ✖ dplyr::summarise()       masks plyr::summarise()
# ✖ dplyr::summarize()       masks plyr::summarize()
# ✖ purrr::transpose()       masks data.table::transpose()
# ✖ tidyr::unpack()          masks Matrix::unpack()
# Loading required package: BSgenome
#
# Loading required package: Biostrings
#
# Loading required package: XVector
#
#
# Attaching package: ‘XVector’
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#
#
# The following object is masked from ‘package:plyr’:
#
#     compact
#
#
#
# Attaching package: ‘Biostrings’
#
#
# The following object is masked from ‘package:base’:
#
#     strsplit
#
#
# Loading required package: rtracklayer

# %%
setwd('/nfs/team205/heart/anndata_objects/8regions/ArchR')
getwd()
# Out:
# [1] "/nfs/team205/heart/anndata_objects/8regions/ArchR"

# %%
# before starting a project we must set the ArchRGenome and default threads for parallelization.
# Setting default genome to Hg38.
addArchRGenome("hg38")
# Out:
# Setting default genome to Hg38.

# %%
# Setting default number of Parallel threads to 16
addArchRThreads(threads = 10)
# Out:
# Setting default number of Parallel threads to 10.

# %% [markdown]
# ## Read in ArchR project

# %%
archr_project_path = '/nfs/team205/heart/anndata_objects/8regions/ArchR/project_output'
proj = loadArchRProject(path = archr_project_path, showLogo = FALSE)
proj
# Out:
# Successfully loaded ArchRProject!
#
#
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /nfs/team205/heart/anndata_objects/8regions/ArchR/project_output
# samples(47): HCAHeart9508627_HCAHeart9508819
#   HCAHeart9508628_HCAHeart9508820 ...
#   HCAHeartST13180618_HCAHeartST13177115
#   HCAHeartST13180619_HCAHeartST13177116
# sampleColData names(1): ArrowFiles
# cellColData names(45): Sample TSSEnrichment ... cell_state Clusters
# numberOfCells(1): 144762
# medianTSS(1): 8.677
# medianFrags(1): 9588

# %%
table(proj$cell_state)
# Out:
#             aCM1             aCM2             aCM3             aCM4
#             3443             7420             1021             1993
#            Adip1            Adip2            Adip3  AVN_bundle_cell
#              896              423               55               26
#       AVN_P_cell                B         B_plasma          CD14+Mo
#               91              238              107              467
#          CD16+Mo        CD4+T_act      CD4+T_naive      CD8+T_cytox
#              964              659              683               94
#         CD8+T_em         CD8+T_te      CD8+T_trans               DC
#              475              283              608              189
#          EC1_cap    EC10_CMC-like          EC2_cap          EC3_cap
#             2763             2064              623              783
#       EC4_immune          EC5_art          EC6_ven  EC7_endocardial
#             1571             2980             2482             2838
#           EC8_ln              FB1              FB2              FB3
#              334             3751            12149             9266
#    FB4_activated              FB5              FB6              ILC
#            11636             3970             1707               29
#    LYVE1+IGF1+MP LYVE1+MP_cycling   LYVE1+TIMD4+MP        MAIT-like
#             3514              675             5725               94
#             Mast             Meso             MoMP        NC1_glial
#              274               62             2126             1350
#   NC2_glial_NGF+             Neut        NK_CD16hi        NK_CD56hi
#              231                4              756              339
#         PC1_vent        PC2_atria          PC3_str     PC4_CMC-like
#             2811             3512             2538               28
#    Purkinje_cell       SAN_P_cell       SMC1_basic         SMC2_art
#               13              169              680              552
#     T/NK_cycling     unclassified             vCM1             vCM2
#               34             4914            13484             3980
#    vCM3_stressed             vCM4             vCM5
#             3750            14057                9

# %%
# remove cell types lower than 10 cells 
cells = names(which(table(proj$cell_state) >= 10))
cells = cells[cells != 'unclassified']
cells

idxSample <- BiocGenerics::which(proj$cell_state %in% cells)
cellsSample <- proj$cellNames[idxSample]
proj = proj[cellsSample, ]
proj
# Out:
#  [1] "aCM1"             "aCM2"             "aCM3"             "aCM4"
#  [5] "Adip1"            "Adip2"            "Adip3"            "AVN_bundle_cell"
#  [9] "AVN_P_cell"       "B"                "B_plasma"         "CD14+Mo"
# [13] "CD16+Mo"          "CD4+T_act"        "CD4+T_naive"      "CD8+T_cytox"
# [17] "CD8+T_em"         "CD8+T_te"         "CD8+T_trans"      "DC"
# [21] "EC1_cap"          "EC10_CMC-like"    "EC2_cap"          "EC3_cap"
# [25] "EC4_immune"       "EC5_art"          "EC6_ven"          "EC7_endocardial"
# [29] "EC8_ln"           "FB1"              "FB2"              "FB3"
# [33] "FB4_activated"    "FB5"              "FB6"              "ILC"
# [37] "LYVE1+IGF1+MP"    "LYVE1+MP_cycling" "LYVE1+TIMD4+MP"   "MAIT-like"
# [41] "Mast"             "Meso"             "MoMP"             "NC1_glial"
# [45] "NC2_glial_NGF+"   "NK_CD16hi"        "NK_CD56hi"        "PC1_vent"
# [49] "PC2_atria"        "PC3_str"          "PC4_CMC-like"     "Purkinje_cell"
# [53] "SAN_P_cell"       "SMC1_basic"       "SMC2_art"         "T/NK_cycling"
# [57] "vCM1"             "vCM2"             "vCM3_stressed"    "vCM4"
#            ___      .______        ______  __    __  .______
#           /   \     |   _  \      /      ||  |  |  | |   _  \
#          /  ^  \    |  |_)  |    |  ,----'|  |__|  | |  |_)  |
#         /  /_\  \   |      /     |  |     |   __   | |      /
#        /  _____  \  |  |\  \\___ |  `----.|  |  |  | |  |\  \\___.
#       /__/     \__\ | _| `._____| \______||__|  |__| | _| `._____|
# class: ArchRProject
# outputDirectory: /nfs/team205/heart/anndata_objects/8regions/ArchR/project_output
# samples(47): HCAHeart9508627_HCAHeart9508819
#   HCAHeart9508628_HCAHeart9508820 ...
#   HCAHeartST13180618_HCAHeartST13177115
#   HCAHeartST13180619_HCAHeartST13177116
# sampleColData names(1): ArrowFiles
# cellColData names(45): Sample TSSEnrichment ... cell_state Clusters
# numberOfCells(1): 139835
# medianTSS(1): 8.699
# medianFrags(1): 9459

# %% [markdown]
# ## Create Pseudo-bulk Replicates

# %%
# set fake sample name
proj$combined_Sample = "1"

# %%
proj = addGroupCoverages(ArchRProj = proj, groupBy = "cell_state", sampleLabels = "combined_Sample",
                        minReplicates = 3,
                        maxReplicates = 3,
                         minCells = 40,
                      maxCells = 500,
                        force = TRUE)
# maxReplicate = sample number
# Out:
# ArchR logging to : ArchRLogs/ArchR-addGroupCoverages-af8cf7cb3-Date-2022-12-14_Time-11-04-08.log
# If there is an issue, please report to github with logFile!
#
# aCM1 (1 of 60) : CellGroups N = 2
#
# aCM2 (2 of 60) : CellGroups N = 2
#
# aCM3 (3 of 60) : CellGroups N = 2
#
# aCM4 (4 of 60) : CellGroups N = 2
#
# Adip1 (5 of 60) : CellGroups N = 2
#
# Adip2 (6 of 60) : CellGroups N = 2
#
# Adip3 (7 of 60) : CellGroups N = 3
#
# AVN_bundle_cell (8 of 60) : CellGroups N = 3
#
# AVN_P_cell (9 of 60) : CellGroups N = 3
#
# B (10 of 60) : CellGroups N = 2
#
# B_plasma (11 of 60) : CellGroups N = 3
#
# CD4+T_act (12 of 60) : CellGroups N = 2
#
# CD4+T_naive (13 of 60) : CellGroups N = 2
#
# CD8+T_cytox (14 of 60) : CellGroups N = 3
#
# CD8+T_em (15 of 60) : CellGroups N = 2
#
# CD8+T_te (16 of 60) : CellGroups N = 2
#
# CD8+T_trans (17 of 60) : CellGroups N = 2
#
# CD14+Mo (18 of 60) : CellGroups N = 2
#
# CD16+Mo (19 of 60) : CellGroups N = 2
#
# DC (20 of 60) : CellGroups N = 2
#
# EC1_cap (21 of 60) : CellGroups N = 2
#
# EC2_cap (22 of 60) : CellGroups N = 2
#
# EC3_cap (23 of 60) : CellGroups N = 2
#
# EC4_immune (24 of 60) : CellGroups N = 2
#
# EC5_art (25 of 60) : CellGroups N = 2
#
# EC6_ven (26 of 60) : CellGroups N = 2
#
# EC7_endocardial (27 of 60) : CellGroups N = 2
#
# EC8_ln (28 of 60) : CellGroups N = 2
#
# EC10_CMC-like (29 of 60) : CellGroups N = 2
#
# FB1 (30 of 60) : CellGroups N = 2
#
# FB2 (31 of 60) : CellGroups N = 2
#
# FB3 (32 of 60) : CellGroups N = 2
#
# FB4_activated (33 of 60) : CellGroups N = 2
#
# FB5 (34 of 60) : CellGroups N = 2
#
# FB6 (35 of 60) : CellGroups N = 2
#
# ILC (36 of 60) : CellGroups N = 3
#
# LYVE1+IGF1+MP (37 of 60) : CellGroups N = 2
#
# LYVE1+MP_cycling (38 of 60) : CellGroups N = 2
#
# LYVE1+TIMD4+MP (39 of 60) : CellGroups N = 2
#
# MAIT-like (40 of 60) : CellGroups N = 3
#
# Mast (41 of 60) : CellGroups N = 2
#
# Meso (42 of 60) : CellGroups N = 3
#
# MoMP (43 of 60) : CellGroups N = 2
#
# NC1_glial (44 of 60) : CellGroups N = 2
#
# NC2_glial_NGF+ (45 of 60) : CellGroups N = 2
#
# NK_CD16hi (46 of 60) : CellGroups N = 2
#
# NK_CD56hi (47 of 60) : CellGroups N = 2
#
# PC1_vent (48 of 60) : CellGroups N = 2
#
# PC2_atria (49 of 60) : CellGroups N = 2
#
# PC3_str (50 of 60) : CellGroups N = 2
#
# PC4_CMC-like (51 of 60) : CellGroups N = 3
#
# Purkinje_cell (52 of 60) : CellGroups N = 3
#
# SAN_P_cell (53 of 60) : CellGroups N = 2
#
# SMC1_basic (54 of 60) : CellGroups N = 2
#
# SMC2_art (55 of 60) : CellGroups N = 2
#
# T/NK_cycling (56 of 60) : CellGroups N = 3
#
# vCM1 (57 of 60) : CellGroups N = 2
#
# vCM2 (58 of 60) : CellGroups N = 2
#
# vCM3_stressed (59 of 60) : CellGroups N = 2
#
# vCM4 (60 of 60) : CellGroups N = 2
#
# 2022-12-14 11:06:06 : Creating Coverage Files!, 1.979 mins elapsed.
#
# 2022-12-14 11:06:06 : Batch Execution w/ safelapply!, 1.979 mins elapsed.
#
# 2022-12-14 11:51:47 : Adding Kmer Bias to Coverage Files!, 47.663 mins elapsed.
#
# Completed Kmer Bias Calculation
#
# Adding Kmer Bias (1 of 131)
#
# Adding Kmer Bias (2 of 131)
#
# Adding Kmer Bias (3 of 131)
#
# Adding Kmer Bias (4 of 131)
#
# Adding Kmer Bias (5 of 131)
#
# Adding Kmer Bias (6 of 131)
#
# Adding Kmer Bias (7 of 131)
#
# Adding Kmer Bias (8 of 131)
#
# Adding Kmer Bias (9 of 131)
#
# Adding Kmer Bias (10 of 131)
#
# Adding Kmer Bias (11 of 131)
#
# Adding Kmer Bias (12 of 131)
#
# Adding Kmer Bias (13 of 131)
#
# Adding Kmer Bias (14 of 131)
#
# Adding Kmer Bias (15 of 131)
#
# Adding Kmer Bias (16 of 131)
#
# Adding Kmer Bias (17 of 131)
#
# Adding Kmer Bias (18 of 131)
#
# Adding Kmer Bias (19 of 131)
#
# Adding Kmer Bias (20 of 131)
#
# Adding Kmer Bias (21 of 131)
#
# Adding Kmer Bias (22 of 131)
#
# Adding Kmer Bias (23 of 131)
#
# Adding Kmer Bias (24 of 131)
#
# Adding Kmer Bias (25 of 131)
#
# Adding Kmer Bias (26 of 131)
#
# Adding Kmer Bias (27 of 131)
#
# Adding Kmer Bias (28 of 131)
#
# Adding Kmer Bias (29 of 131)
#
# Adding Kmer Bias (30 of 131)
#
# Adding Kmer Bias (31 of 131)
#
# Adding Kmer Bias (32 of 131)
#
# Adding Kmer Bias (33 of 131)
#
# Adding Kmer Bias (34 of 131)
#
# Adding Kmer Bias (35 of 131)
#
# Adding Kmer Bias (36 of 131)
#
# Adding Kmer Bias (37 of 131)
#
# Adding Kmer Bias (38 of 131)
#
# Adding Kmer Bias (39 of 131)
#
# Adding Kmer Bias (40 of 131)
#
# Adding Kmer Bias (41 of 131)
#
# Adding Kmer Bias (42 of 131)
#
# Adding Kmer Bias (43 of 131)
#
# Adding Kmer Bias (44 of 131)
#
# Adding Kmer Bias (45 of 131)
#
# Adding Kmer Bias (46 of 131)
#
# Adding Kmer Bias (47 of 131)
#
# Adding Kmer Bias (48 of 131)
#
# Adding Kmer Bias (49 of 131)
#
# Adding Kmer Bias (50 of 131)
#
# Adding Kmer Bias (51 of 131)
#
# Adding Kmer Bias (52 of 131)
#
# Adding Kmer Bias (53 of 131)
#
# Adding Kmer Bias (54 of 131)
#
# Adding Kmer Bias (55 of 131)
#
# Adding Kmer Bias (56 of 131)
#
# Adding Kmer Bias (57 of 131)
#
# Adding Kmer Bias (58 of 131)
#
# Adding Kmer Bias (59 of 131)
#
# Adding Kmer Bias (60 of 131)
#
# Adding Kmer Bias (61 of 131)
#
# Adding Kmer Bias (62 of 131)
#
# Adding Kmer Bias (63 of 131)
#
# Adding Kmer Bias (64 of 131)
#
# Adding Kmer Bias (65 of 131)
#
# Adding Kmer Bias (66 of 131)
#
# Adding Kmer Bias (67 of 131)
#
# Adding Kmer Bias (68 of 131)
#
# Adding Kmer Bias (69 of 131)
#
# Adding Kmer Bias (70 of 131)
#
# Adding Kmer Bias (71 of 131)
#
# Adding Kmer Bias (72 of 131)
#
# Adding Kmer Bias (73 of 131)
#
# Adding Kmer Bias (74 of 131)
#
# Adding Kmer Bias (75 of 131)
#
# Adding Kmer Bias (76 of 131)
#
# Adding Kmer Bias (77 of 131)
#
# Adding Kmer Bias (78 of 131)
#
# Adding Kmer Bias (79 of 131)
#
# Adding Kmer Bias (80 of 131)
#
# Adding Kmer Bias (81 of 131)
#
# Adding Kmer Bias (82 of 131)
#
# Adding Kmer Bias (83 of 131)
#
# Adding Kmer Bias (84 of 131)
#
# Adding Kmer Bias (85 of 131)
#
# Adding Kmer Bias (86 of 131)
#
# Adding Kmer Bias (87 of 131)
#
# Adding Kmer Bias (88 of 131)
#
# Adding Kmer Bias (89 of 131)
#
# Adding Kmer Bias (90 of 131)
#
# Adding Kmer Bias (91 of 131)
#
# Adding Kmer Bias (92 of 131)
#
# Adding Kmer Bias (93 of 131)
#
# Adding Kmer Bias (94 of 131)
#
# Adding Kmer Bias (95 of 131)
#
# Adding Kmer Bias (96 of 131)
#
# Adding Kmer Bias (97 of 131)
#
# Adding Kmer Bias (98 of 131)
#
# Adding Kmer Bias (99 of 131)
#
# Adding Kmer Bias (100 of 131)
#
# Adding Kmer Bias (101 of 131)
#
# Adding Kmer Bias (102 of 131)
#
# Adding Kmer Bias (103 of 131)
#
# Adding Kmer Bias (104 of 131)
#
# Adding Kmer Bias (105 of 131)
#
# Adding Kmer Bias (106 of 131)
#
# Adding Kmer Bias (107 of 131)
#
# Adding Kmer Bias (108 of 131)
#
# Adding Kmer Bias (109 of 131)
#
# Adding Kmer Bias (110 of 131)
#
# Adding Kmer Bias (111 of 131)
#
# Adding Kmer Bias (112 of 131)
#
# Adding Kmer Bias (113 of 131)
#
# Adding Kmer Bias (114 of 131)
#
# Adding Kmer Bias (115 of 131)
#
# Adding Kmer Bias (116 of 131)
#
# Adding Kmer Bias (117 of 131)
#
# Adding Kmer Bias (118 of 131)
#
# Adding Kmer Bias (119 of 131)
#
# Adding Kmer Bias (120 of 131)
#
# Adding Kmer Bias (121 of 131)
#
# Adding Kmer Bias (122 of 131)
#
# Adding Kmer Bias (123 of 131)
#
# Adding Kmer Bias (124 of 131)
#
# Adding Kmer Bias (125 of 131)
#
# Adding Kmer Bias (126 of 131)
#
# Adding Kmer Bias (127 of 131)
#
# Adding Kmer Bias (128 of 131)
#
# Adding Kmer Bias (129 of 131)
#
# Adding Kmer Bias (130 of 131)
#
# Adding Kmer Bias (131 of 131)
#
# 2022-12-14 11:59:15 : Finished Creation of Coverage Files!, 55.124 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addGroupCoverages-af8cf7cb3-Date-2022-12-14_Time-11-04-08.log

# %% [markdown]
# ## Calling peaks

# %%
# need to make sure MACS2 is the latest version
# at terminal
pip install --upgrade --force-reinstall MACS2

# %%
start_time <- Sys.time()

proj <- addReproduciblePeakSet(
    ArchRProj = proj, 
    groupBy = "cell_state", 
    threads = 10,
    reproducibility = "2",
)

end_time <- Sys.time()
end_time - start_time
# Out:
# Searching For MACS2..
#
# Found with $path!
#
# ArchR logging to : ArchRLogs/ArchR-addReproduciblePeakSet-afd9009b7-Date-2022-12-14_Time-11-59-16.log
# If there is an issue, please report to github with logFile!
#
# Calling Peaks with Macs2
#
# 2022-12-14 11:59:17 : Peak Calling Parameters!, 0.027 mins elapsed.
#                             Group nCells nCellsUsed nReplicates nMin nMax
# aCM1                         aCM1   3443        580           2   80  500
# aCM2                         aCM2   7420        580           2   80  500
# aCM3                         aCM3   1021        580           2   80  500
# aCM4                         aCM4   1993        580           2   80  500
# Adip1                       Adip1    896        580           2   80  500
# Adip2                       Adip2    423        423           2   80  343
# Adip3                       Adip3     55         55           3   40   40
# AVN_bundle_cell   AVN_bundle_cell     26         26           3   15   22
# AVN_P_cell             AVN_P_cell     91         79           3   40   40
# B                               B    238        238           2   80  158
# B_plasma                 B_plasma    107         84           3   40   40
# CD4+T_act               CD4+T_act    659        580           2   80  500
# CD4+T_naive           CD4+T_naive    683        580           2   80  500
# CD8+T_cytox           CD8+T_cytox     94         77           3   40   40
# CD8+T_em                 CD8+T_em    475        475           2   80  395
# CD8+T_te                 CD8+T_te    283        283           2   80  203
# CD8+T_trans           CD8+T_trans    608        580           2   80  500
# CD14+Mo                   CD14+Mo    467        467           2   80  387
# CD16+Mo                   CD16+Mo    964        580           2   80  500
# DC                             DC    189        189           2   80  109
# EC1_cap                   EC1_cap   2763        580           2   80  500
# EC2_cap                   EC2_cap    623        580           2   80  500
# EC3_cap                   EC3_cap    783        580           2   80  500
# EC4_immune             EC4_immune   1571        580           2   80  500
# EC5_art                   EC5_art   2980        580           2   80  500
# EC6_ven                   EC6_ven   2482        580           2   80  500
# EC7_endocardial   EC7_endocardial   2838        580           2   80  500
# EC8_ln                     EC8_ln    334        334           2   80  254
# EC10_CMC-like       EC10_CMC-like   2064        580           2   80  500
# FB1                           FB1   3751        580           2   80  500
# FB2                           FB2  12149        580           2   80  500
# FB3                           FB3   9266        580           2   80  500
# FB4_activated       FB4_activated  11636        580           2   80  500
# FB5                           FB5   3970        580           2   80  500
# FB6                           FB6   1707        580           2   80  500
# ILC                           ILC     29         28           3   18   21
# LYVE1+IGF1+MP       LYVE1+IGF1+MP   3514        580           2   80  500
# LYVE1+MP_cycling LYVE1+MP_cycling    675        580           2   80  500
# LYVE1+TIMD4+MP     LYVE1+TIMD4+MP   5725        580           2   80  500
# MAIT-like               MAIT-like     94         77           3   40   40
# Mast                         Mast    274        274           2   80  194
# Meso                         Meso     62         62           3   40   40
# MoMP                         MoMP   2126        580           2   80  500
# NC1_glial               NC1_glial   1350        580           2   80  500
# NC2_glial_NGF+     NC2_glial_NGF+    231        231           2   80  151
# NK_CD16hi               NK_CD16hi    756        580           2   80  500
# NK_CD56hi               NK_CD56hi    339        339           2   80  259
# PC1_vent                 PC1_vent   2811        580           2   80  500
# PC2_atria               PC2_atria   3512        580           2   80  500
# PC3_str                   PC3_str   2538        580           2   80  500
# PC4_CMC-like         PC4_CMC-like     28         27           3   16   20
# Purkinje_cell       Purkinje_cell     13         13           3   10   13
# SAN_P_cell             SAN_P_cell    169        169           2   80   89
# SMC1_basic             SMC1_basic    680        580           2   80  500
# SMC2_art                 SMC2_art    552        552           2   80  472
# T/NK_cycling         T/NK_cycling     34         33           3   20   27
# vCM1                         vCM1  13484        580           2   80  500
# vCM2                         vCM2   3980        580           2   80  500
# vCM3_stressed       vCM3_stressed   3750        580           2   80  500
# vCM4                         vCM4  14057        580           2   80  500
#                  maxPeaks
# aCM1               150000
# aCM2               150000
# aCM3               150000
# aCM4               150000
# Adip1              150000
# Adip2              150000
# Adip3               27500
# AVN_bundle_cell     13000
# AVN_P_cell          39500
# B                  119000
# B_plasma            42000
# CD4+T_act          150000
# CD4+T_naive        150000
# CD8+T_cytox         38500
# CD8+T_em           150000
# CD8+T_te           141500
# CD8+T_trans        150000
# CD14+Mo            150000
# CD16+Mo            150000
# DC                  94500
# EC1_cap            150000
# EC2_cap            150000
# EC3_cap            150000
# EC4_immune         150000
# EC5_art            150000
# EC6_ven            150000
# EC7_endocardial    150000
# EC8_ln             150000
# EC10_CMC-like      150000
# FB1                150000
# FB2                150000
# FB3                150000
# FB4_activated      150000
# FB5                150000
# FB6                150000
# ILC                 14000
# LYVE1+IGF1+MP      150000
# LYVE1+MP_cycling   150000
# LYVE1+TIMD4+MP     150000
# MAIT-like           38500
# Mast               137000
# Meso                31000
# MoMP               150000
# NC1_glial          150000
# NC2_glial_NGF+     115500
# NK_CD16hi          150000
# NK_CD56hi          150000
# PC1_vent           150000
# PC2_atria          150000
# PC3_str            150000
# PC4_CMC-like        13500
# Purkinje_cell        6500
# SAN_P_cell          84500
# SMC1_basic         150000
# SMC2_art           150000
# T/NK_cycling        16500
# vCM1               150000
# vCM2               150000
# vCM3_stressed      150000
# vCM4               150000
# 2022-12-14 11:59:17 : Batching Peak Calls!, 0.027 mins elapsed.
#
# 2022-12-14 11:59:17 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# 2022-12-14 12:13:32 : Identifying Reproducible Peaks!, 14.267 mins elapsed.
#
# 2022-12-14 12:14:41 : Creating Union Peak Set!, 15.417 mins elapsed.
#
# Converged after 12 iterations!
#
# Plotting Ggplot!
#
# 2022-12-14 12:14:57 : Finished Creating Union Peak Set (429828)!, 15.698 mins elapsed.
# Time difference of 15.70521 mins

# %% [markdown]
# ## Add Peak matrix

# %%
proj = addPeakMatrix(proj)
# Out:
# ArchR logging to : ArchRLogs/ArchR-addPeakMatrix-af418dfe32-Date-2022-12-14_Time-12-14-57.log
# If there is an issue, please report to github with logFile!
#
# 2022-12-14 12:14:58 : Batch Execution w/ safelapply!, 0 mins elapsed.
#
# ArchR logging successful to : ArchRLogs/ArchR-addPeakMatrix-af418dfe32-Date-2022-12-14_Time-12-14-57.log

# %%
saveArchRProject(ArchRProj = proj, outputDirectory = "project_output", load = FALSE)
# Out:
# Saving ArchRProject...
