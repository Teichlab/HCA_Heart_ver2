# %% [markdown]
# * only SAN/AVN cells
# * only New data

# %% [markdown]
# ## Import modules

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import scrublet as scr
import session_info

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi = 160, color_map = 'RdPu', dpi_save = 180, vector_friendly = True, format = 'svg')
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.3.4
# numpy               1.20.1
# pandas              1.1.4
# scanpy              1.7.1
# scrublet            NA
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 8.1.2
# anndata             0.7.5
# anyio               NA
# attr                20.3.0
# babel               2.9.0
# backcall            0.2.0
# brotli              NA
# cairo               1.20.0
# certifi             2020.12.05
# cffi                1.14.5
# chardet             4.0.0
# cloudpickle         1.6.0
# colorama            0.4.4
# cycler              0.10.0
# cython_runtime      NA
# cytoolz             0.11.0
# dask                2021.03.1
# dateutil            2.8.1
# decorator           4.4.2
# fsspec              0.8.7
# get_version         2.1
# google              NA
# h5py                2.10.0
# idna                2.10
# igraph              0.8.3
# ipykernel           5.5.0
# ipython_genutils    0.2.0
# jedi                0.18.0
# jinja2              2.11.3
# joblib              1.0.1
# json5               NA
# jsonschema          3.2.0
# jupyter_server      1.4.1
# jupyterlab_server   2.3.0
# kiwisolver          1.3.1
# legacy_api_wrap     0.0.0
# leidenalg           0.8.3
# llvmlite            0.34.0
# louvain             0.7.0
# markupsafe          1.1.1
# mpl_toolkits        NA
# natsort             7.1.1
# nbclassic           NA
# nbformat            5.1.2
# numba               0.51.2
# numexpr             2.7.3
# packaging           20.9
# parso               0.8.1
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# prometheus_client   NA
# prompt_toolkit      3.0.16
# psutil              5.8.0
# ptyprocess          0.7.0
# pvectorc            NA
# pyarrow             0.16.0
# pygments            2.8.0
# pyparsing           2.4.7
# pyrsistent          NA
# pytoml              NA
# pytz                2021.1
# requests            2.25.1
# ruamel              NA
# scipy               1.6.1
# send2trash          NA
# setuptools_scm      NA
# simplejson          3.17.2
# sinfo               0.3.1
# six                 1.15.0
# sklearn             0.22
# sniffio             1.2.0
# socks               1.7.1
# sphinxcontrib       NA
# storemagic          NA
# tables              3.6.1
# tblib               1.7.0
# texttable           1.6.3
# tlz                 0.11.0
# toolz               0.11.1
# tornado             6.1
# traitlets           5.0.5
# typing_extensions   NA
# uritemplate         3.0.1
# urllib3             1.26.3
# wcwidth             0.2.5
# yaml                5.1.2
# zmq                 22.0.3
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.21.0
# jupyter_client      6.1.11
# jupyter_core        4.7.1
# jupyterlab          3.0.9
# notebook            6.2.0
# -----
# Python 3.8.8 | packaged by conda-forge | (default, Feb 20 2021, 16:22:27) [GCC 9.3.0]
# Linux-4.15.0-156-generic-x86_64-with-glibc2.10
# -----
# Session information updated at 2022-12-08 13:49
# </pre>
# </details>

# %% [markdown]
# ## Functions

# %%
"""Functions for downstream work with outputs of remove-background."""

# to read cellbender outputs<br>
# https://github.com/broadinstitute/CellBender/issues/57

import tables
import numpy as np
import scipy.sparse as sp
from typing import Dict


def dict_from_h5(file: str) -> Dict[str, np.ndarray]:
    """Read in everything from an h5 file and put into a dictionary."""
    d = {}
    with tables.open_file(file) as f:
        # read in everything
        for array in f.walk_nodes("/", "Array"):
            d[array.name] = array.read()
    return d


def anndata_from_h5(file: str,
                    analyzed_barcodes_only: bool = True) -> 'anndata.AnnData':
    """Load an output h5 file into an AnnData object for downstream work.

    Args:
        file: The h5 file
        analyzed_barcodes_only: False to load all barcodes, so that the size of
            the AnnData object will match the size of the input raw count matrix.
            True to load a limited set of barcodes: only those analyzed by the
            algorithm. This allows relevant latent variables to be loaded
            properly into adata.obs and adata.obsm, rather than adata.uns.

    Returns:
        adata: The anndata object, populated with inferred latent variables
            and metadata.

    """

    try:
        import anndata
    except ImportError:
        raise ImportError('The anndata package must be installed to use the '
                          'function anndata_from_h5()')

    d = dict_from_h5(file)
    X = sp.csc_matrix((d.pop('data'), d.pop('indices'), d.pop('indptr')),
                      shape=d.pop('shape')).transpose().tocsr()

    if analyzed_barcodes_only:
        if 'barcodes_analyzed_inds' in d.keys():
            X = X[d['barcodes_analyzed_inds'], :]
            d['barcodes'] = d['barcodes'][d['barcodes_analyzed_inds']]
        elif 'barcode_indices_for_latents' in d.keys():
            X = X[d['barcode_indices_for_latents'], :]
            d['barcodes'] = d['barcodes'][d['barcode_indices_for_latents']]
        else:
            print('Warning: analyzed_barcodes_only=True, but the key '
                  '"barcodes_analyzed_inds" or "barcode_indices_for_latents" '
                  'is missing from the h5 file. '
                  'Will output all barcodes, and proceed as if '
                  'analyzed_barcodes_only=False')

    # Construct the count matrix.
    adata = anndata.AnnData(X=X,
                            obs={'barcode': d.pop('barcodes').astype(str)},
                            var={'gene_name': (d.pop('gene_names') if 'gene_names' in d.keys()
                                               else d.pop('name')).astype(str)})
    adata.obs.set_index('barcode', inplace=True)
    adata.var.set_index('gene_name', inplace=True)

    # Add other information to the adata object in the appropriate slot.
    for key, value in d.items():
        try:
            value = np.asarray(value)
            if len(value.shape) == 0:
                adata.uns[key] = value
            elif value.shape[0] == X.shape[0]:
                if (len(value.shape) < 2) or (value.shape[1] < 2):
                    adata.obs[key] = value
                else:
                    adata.obsm[key] = value
            elif value.shape[0] == X.shape[1]:
                if value.dtype.name.startswith('bytes'):
                    adata.var[key] = value.astype(str)
                else:
                    adata.var[key] = value
            else:
                adata.uns[key] = value
        except Exception:
            print('Unable to load data into AnnData: ', key, value, type(value))

    if analyzed_barcodes_only:
        for col in adata.obs.columns[adata.obs.columns.str.startswith('barcodes_analyzed')
                                     | adata.obs.columns.str.startswith('barcode_indices')]:
            try:
                del adata.obs[col]
            except Exception:
                pass

    return adata

# %%
# from https://github.com/Teichlab/mapcloud/blob/master/scripts/starsolo/postprocess.py

from statsmodels.stats.multitest import multipletests
# from emptydrops.matrix import CountMatrix
# from emptydrops import find_nonambient_barcodes
import scrublet as scr
import scanpy as sc
import pandas as pd
import numpy as np
import scipy

#some functions that Ni uses in scanpy scripts to run scrublet
#which in turn are inspired by my original notebook on the matter
#(extracted from scanpy_scripts 0.2.10 to get around scanpy version incompatibility)
def test_outlier(x, upper_mad_only=True):
	med = np.median(x)
	if upper_mad_only:
		mad = np.median(x[x>med] - med) * 1.4826
	else:
		mad = np.median(np.abs(x - med)) * 1.4826
	pvals = 1 - scipy.stats.norm.cdf(x, loc=med, scale=mad)
	bh_pvals = multipletests(pvals, method='fdr_bh')[1]
	return pvals, bh_pvals

def run_scrublet(adata, resolution_function=None):
	old_verbosity = sc.settings.verbosity
	sc.settings.verbosity = 1
	if resolution_function is None:
		resolution_function = lambda x: np.maximum(np.maximum(np.log10(x)-1, 0)**2, 0.1)
	scrub = scr.Scrublet(adata.X)
	#this has the potential to brick for poor quality data
	#if so, abort it and everything downstream
	try:
		ds, pd = scrub.scrub_doublets(verbose=False)
	except:
		return
	adata.obs['scrublet_score'] = ds

	adata_copy = adata.copy()
	sc.pp.filter_genes(adata_copy, min_cells=3)
	sc.pp.normalize_total(adata_copy, target_sum=1e4)
	sc.pp.log1p(adata_copy)
	sc.pp.highly_variable_genes(adata_copy, min_mean=0.0125, max_mean=3, min_disp=0.5, subset=True)
	sc.pp.scale(adata_copy, zero_center=False)
	sc.pp.pca(adata_copy, svd_solver='arpack', zero_center=False)
	sc.pp.neighbors(adata_copy, n_pcs=30)
	sc.tl.umap(adata_copy)
	sc.tl.leiden(adata_copy, resolution=1)
	for clst in np.unique(adata_copy.obs['leiden']):
		clst_size = sum(adata_copy.obs['leiden'] == clst)
		sc.tl.leiden(adata_copy, restrict_to=('leiden', [clst]), resolution=resolution_function(clst_size), key_added='leiden_R')
		adata_copy.obs['leiden'] = adata_copy.obs['leiden_R']
	clst_meds = []
	for clst in np.unique(adata_copy.obs['leiden']):
		k = adata_copy.obs['leiden'] == clst
		clst_med = np.median(adata_copy.obs.loc[k, 'scrublet_score'])
		adata_copy.obs.loc[k, 'cluster_scrublet_score'] = clst_med
		clst_meds.append(clst_med)
	clst_meds = np.array(clst_meds)
	pvals, bh_pvals = test_outlier(clst_meds)
	for i, clst in enumerate(np.unique(adata_copy.obs['leiden'])):
		k = adata_copy.obs['leiden'] == clst
		adata_copy.obs.loc[k, 'pval'] = pvals[i]
		adata_copy.obs.loc[k, 'bh_pval'] = bh_pvals[i]
	sc.settings.verbosity = old_verbosity
	#need to also export the clustering, for soupx purposes
	adata.obs['scrublet_leiden'] = adata_copy.obs['leiden']
	adata.obs['scrublet_score'] = adata_copy.obs['scrublet_score']
	adata.obs['cluster_scrublet_score'] = adata_copy.obs['cluster_scrublet_score']
	adata.obs['doublet_pval'] = adata_copy.obs['pval']
	adata.obs['doublet_bh_pval'] = adata_copy.obs['bh_pval']
	del adata_copy

# %% [markdown]
# ## Create anndata object

# %%
# read in metadata
metadata = pd.read_csv('/nfs/team205/heart/anndata_objects/8regions/metadata/HeartTeamSamples_Mappeddata_20221208.csv', sep = ',', index_col = None)
metadata = metadata[metadata['Publication']=='8regions_revision']

print(metadata['modality'].value_counts())
# Out:
# Multiome-ATAC    17
# Multiome-RNA     17
# Visium            8
# Name: modality, dtype: int64

# %%
# select modality
metadata = metadata[metadata['modality']=='Multiome-RNA']

# select SAN
metadata = metadata[metadata['region'].isin(['SAN','AVN'])]
metadata
# Out:
#                      ID                    CombinedID_Multiome  \
# 473  HCAHeartST13146201  HCAHeartST13146201_HCAHeartST13129134
# 474  HCAHeartST13146202  HCAHeartST13146202_HCAHeartST13129135
# 475  HCAHeartST13146203  HCAHeartST13146203_HCAHeartST13129136
# 476  HCAHeartST13146204  HCAHeartST13146204_HCAHeartST13129137
# 477  HCAHeartST13146205  HCAHeartST13146205_HCAHeartST13129138
# 478  HCAHeartST13146206  HCAHeartST13146206_HCAHeartST13129139
# 479  HCAHeartST13146207  HCAHeartST13146207_HCAHeartST13129140
# 480  HCAHeartST13146208  HCAHeartST13146208_HCAHeartST13129141
# 543  HCAHeartST13168796  HCAHeartST13168796_HCAHeartST13167740
# 548  HCAHeartST13189995  HCAHeartST13189995_HCAHeartST13188800
# 549  HCAHeartST13189996  HCAHeartST13189996_HCAHeartST13188801
# 550  HCAHeartST13189997  HCAHeartST13189997_HCAHeartST13188802
# 581  HCAHeartST13180615  HCAHeartST13180615_HCAHeartST13177112
# 582  HCAHeartST13180616  HCAHeartST13180616_HCAHeartST13177113
# 583  HCAHeartST13180617  HCAHeartST13180617_HCAHeartST13177114
# 584  HCAHeartST13180618  HCAHeartST13180618_HCAHeartST13177115
# 585  HCAHeartST13180619  HCAHeartST13180619_HCAHeartST13177116
#
#            Publication Foetal_or_Adult       Provider  \
# 473  8regions_revision           Adult  Sanger, Heart
# 474  8regions_revision           Adult  Sanger, Heart
# 475  8regions_revision           Adult  Sanger, Heart
# 476  8regions_revision           Adult  Sanger, Heart
# 477  8regions_revision           Adult  Sanger, Heart
# 478  8regions_revision           Adult  Sanger, Heart
# 479  8regions_revision           Adult  Sanger, Heart
# 480  8regions_revision           Adult  Sanger, Heart
# 543  8regions_revision           Adult  Sanger, Heart
# 548  8regions_revision           Adult  Sanger, Heart
# 549  8regions_revision           Adult  Sanger, Heart
# 550  8regions_revision           Adult  Sanger, Heart
# 581  8regions_revision           Adult  Sanger, Heart
# 582  8regions_revision           Adult  Sanger, Heart
# 583  8regions_revision           Adult  Sanger, Heart
# 584  8regions_revision           Adult  Sanger, Heart
# 585  8regions_revision           Adult  Sanger, Heart
#
#                                           Chemistry           Mapping_ver  \
# 473  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 474  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 475  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 476  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 477  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 478  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 479  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 480  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 543  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 548  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 549  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 550  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 581  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 582  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 583  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 584  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
# 585  Single Cell Multiome ATAC + Gene Expression v1  cellranger-arc-2.0.0
#
#         Reference_genome Mapping_date  \
# 473  GRCh38-2020-A-2.0.0          NaN
# 474  GRCh38-2020-A-2.0.0          NaN
# 475  GRCh38-2020-A-2.0.0          NaN
# 476  GRCh38-2020-A-2.0.0          NaN
# 477  GRCh38-2020-A-2.0.0          NaN
# 478  GRCh38-2020-A-2.0.0          NaN
# 479  GRCh38-2020-A-2.0.0          NaN
# 480  GRCh38-2020-A-2.0.0          NaN
# 543  GRCh38-2020-A-2.0.0          NaN
# 548  GRCh38-2020-A-2.0.0          NaN
# 549  GRCh38-2020-A-2.0.0          NaN
# 550  GRCh38-2020-A-2.0.0          NaN
# 581  GRCh38-2020-A-2.0.0          NaN
# 582  GRCh38-2020-A-2.0.0          NaN
# 583  GRCh38-2020-A-2.0.0          NaN
# 584  GRCh38-2020-A-2.0.0          NaN
# 585  GRCh38-2020-A-2.0.0          NaN
#
#                                          Mapping_iRODS  ... region  \
# 473  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 474  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 475  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 476  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 477  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 478  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 479  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 480  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 543  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 548  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 549  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    AVN
# 550  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    AVN
# 581  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 582  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 583  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    SAN
# 584  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    AVN
# 585  /seq/illumina/cellranger-arc/cellranger-arc200...  ...    AVN
#
#     region_finest    age  gender facility cell_or_nuclei      modality  \
# 473            na  20-25    Male   Sanger         Nuclei  Multiome-RNA
# 474            na  20-25    Male   Sanger         Nuclei  Multiome-RNA
# 475            na  20-25    Male   Sanger         Nuclei  Multiome-RNA
# 476            na  45-50    Male   Sanger         Nuclei  Multiome-RNA
# 477            na  45-50    Male   Sanger         Nuclei  Multiome-RNA
# 478            na  45-50    Male   Sanger         Nuclei  Multiome-RNA
# 479            na  60-65  Female   Sanger         Nuclei  Multiome-RNA
# 480            na  60-65  Female   Sanger         Nuclei  Multiome-RNA
# 543           SAN  45-50  Female   Sanger         Nuclei  Multiome-RNA
# 548           SAN  70-75  Female   Sanger         Nuclei  Multiome-RNA
# 549           AVN  70-75  Female   Sanger         Nuclei  Multiome-RNA
# 550           AVN  70-75  Female   Sanger         Nuclei  Multiome-RNA
# 581           SAN  40-45    Male   Sanger         Nuclei  Multiome-RNA
# 582           SAN  40-45    Male   Sanger         Nuclei  Multiome-RNA
# 583           SAN  40-45    Male   Sanger         Nuclei  Multiome-RNA
# 584           AVN  40-45    Male   Sanger         Nuclei  Multiome-RNA
# 585           AVN  40-45    Male   Sanger         Nuclei  Multiome-RNA
#
#          kit_10x flushed   status
# 473  Multiome-v1     yes  Healthy
# 474  Multiome-v1     yes  Healthy
# 475  Multiome-v1     yes  Healthy
# 476  Multiome-v1     yes  Healthy
# 477  Multiome-v1     yes  Healthy
# 478  Multiome-v1     yes  Healthy
# 479  Multiome-v1     yes  Healthy
# 480  Multiome-v1     yes  Healthy
# 543  Multiome-v1     yes  Healthy
# 548  Multiome-v1     yes  Healthy
# 549  Multiome-v1     yes  Healthy
# 550  Multiome-v1     yes  Healthy
# 581  Multiome-v1     yes  Healthy
# 582  Multiome-v1     yes  Healthy
# 583  Multiome-v1     yes  Healthy
# 584  Multiome-v1     yes  Healthy
# 585  Multiome-v1     yes  Healthy
#
# [17 rows x 33 columns]

# %%
########### editted: put id to var_names ###########

# read in
adatas=[]
for i in range(len(metadata)):
    print(metadata.iloc[i]['combinedID'])
    
    path=metadata.iloc[i]['CellBender_out']
    adatas.append(anndata_from_h5(path + '/' + path.split('/')[-1] + '_cellbender_out_filtered.h5', analyzed_barcodes_only=False))
    del path
    
    # replace var_names with gene_id 
    adatas[i].var.reset_index(inplace=True)
    adatas[i].var.set_index('id',inplace=True)
    
    # modify barcodes
    adatas[i].obs.index = metadata.iloc[i]['combinedID'] + '_' + adatas[i].obs.index 
    
    # add metadata
    for col in ['sangerID','combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age',
                'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x','flushed']:
        adatas[i].obs[col] = metadata.iloc[i][col]


# concatenate
adata = adatas[0].concatenate(adatas[1:], index_unique = None, batch_key=None)
adata.shape
# Out:
# HCAHeartST13146201_HCAHeartST13129134
# HCAHeartST13146202_HCAHeartST13129135
# HCAHeartST13146203_HCAHeartST13129136
# HCAHeartST13146204_HCAHeartST13129137
# HCAHeartST13146205_HCAHeartST13129138
# HCAHeartST13146206_HCAHeartST13129139
# HCAHeartST13146207_HCAHeartST13129140
# HCAHeartST13146208_HCAHeartST13129141
# HCAHeartST13168796_HCAHeartST13167740
# HCAHeartST13189995_HCAHeartST13188800
# HCAHeartST13189996_HCAHeartST13188801
# HCAHeartST13189997_HCAHeartST13188802
# HCAHeartST13180615_HCAHeartST13177112
# HCAHeartST13180616_HCAHeartST13177113
# HCAHeartST13180617_HCAHeartST13177114
# HCAHeartST13180618_HCAHeartST13177115
# HCAHeartST13180619_HCAHeartST13177116
# (146652, 36601)

# %%
adata.obs['combinedID'].value_counts()
# Out:
# HCAHeartST13180617_HCAHeartST13177114    16625
# HCAHeartST13180615_HCAHeartST13177112    16497
# HCAHeartST13189996_HCAHeartST13188801    15965
# HCAHeartST13180616_HCAHeartST13177113    12300
# HCAHeartST13180618_HCAHeartST13177115    10480
# HCAHeartST13189997_HCAHeartST13188802    10159
# HCAHeartST13189995_HCAHeartST13188800     9365
# HCAHeartST13180619_HCAHeartST13177116     9001
# HCAHeartST13168796_HCAHeartST13167740     8619
# HCAHeartST13146207_HCAHeartST13129140     7593
# HCAHeartST13146204_HCAHeartST13129137     6206
# HCAHeartST13146205_HCAHeartST13129138     5833
# HCAHeartST13146206_HCAHeartST13129139     4770
# HCAHeartST13146208_HCAHeartST13129141     4392
# HCAHeartST13146202_HCAHeartST13129135     4286
# HCAHeartST13146203_HCAHeartST13129136     3515
# HCAHeartST13146201_HCAHeartST13129134     1046
# Name: combinedID, dtype: int64

# %% [markdown]
# ## Run scrublet

# %%
# %%time

# per rxn
for i,ID in enumerate(adata.obs['combinedID'].unique()):
    print(ID)
    
    ad = adata[adata.obs['combinedID'] == ID].copy()
    run_scrublet(ad)
    if i==0:
        meta = ad.obs
    else:
        meta = pd.concat([meta, ad.obs])
    del ad
# Out:
# HCAHeartST13146201_HCAHeartST13129134
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13146202_HCAHeartST13129135
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13146203_HCAHeartST13129136
# HCAHeartST13146204_HCAHeartST13129137
# HCAHeartST13146205_HCAHeartST13129138
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13146206_HCAHeartST13129139
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13146207_HCAHeartST13129140
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13146208_HCAHeartST13129141
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13168796_HCAHeartST13167740
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13189995_HCAHeartST13188800
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13189996_HCAHeartST13188801
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13189997_HCAHeartST13188802
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13180615_HCAHeartST13177112
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13180616_HCAHeartST13177113
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13180617_HCAHeartST13177114
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13180618_HCAHeartST13177115
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# HCAHeartST13180619_HCAHeartST13177116
# /opt/conda/envs/teichlab/lib/python3.8/site-packages/scrublet/helper_functions.py:321: RuntimeWarning: divide by zero encountered in true_divide
#   w.setdiag(float(target_total) / tots_use)
# WARNING: Some cells have total count of genes equal to zero
# CPU times: user 32min 23s, sys: 16min 30s, total: 48min 54s
# Wall time: 12min 21s

# %% [markdown]
# ## Add scrublet outputs to adata

# %%
meta_scrub = meta[['scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval']].copy()
meta_scrub.shape
# Out:
# (146652, 5)

# %%
if meta_scrub.reindex(adata.obs.index).index.equals(adata.obs.index):
    adata.obs = pd.concat([adata.obs, meta_scrub.reindex(adata.obs.index)], axis=1)
else:
    raise Exception('Different barcodes in meta and adata')

# %%
adata.obs.head()
# Out:
#                                                     latent_RT_efficiency  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...              3.620071
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...              3.613875
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...              3.296565
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...              3.371856
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...              3.205887
#
#                                                     latent_cell_probability  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...                      1.0
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...                      1.0
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...                      1.0
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...                      1.0
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...                      1.0
#
#                                                     latent_scale  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...  24020.279297
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...  23438.445312
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...  15958.253906
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...  18051.541016
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...  15712.057617
#
#                                                               sangerID  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...  HCAHeartST13146201
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...  HCAHeartST13146201
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...  HCAHeartST13146201
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...  HCAHeartST13146201
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...  HCAHeartST13146201
#
#                                                                                combinedID  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...  HCAHeartST13146201_HCAHeartST13129134
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...  HCAHeartST13146201_HCAHeartST13129134
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...  HCAHeartST13146201_HCAHeartST13129134
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...  HCAHeartST13146201_HCAHeartST13129134
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...  HCAHeartST13146201_HCAHeartST13129134
#
#                                                    donor donor_type region  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...  AV10        DBD    SAN
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...  AV10        DBD    SAN
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...  AV10        DBD    SAN
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...  AV10        DBD    SAN
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...  AV10        DBD    SAN
#
#                                                    region_finest    age  ...  \
# barcode                                                                  ...
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...            na  20-25  ...
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...            na  20-25  ...
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...            na  20-25  ...
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...            na  20-25  ...
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...            na  20-25  ...
#
#                                                    facility cell_or_nuclei  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...   Sanger         Nuclei
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...   Sanger         Nuclei
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...   Sanger         Nuclei
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...   Sanger         Nuclei
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...   Sanger         Nuclei
#
#                                                         modality      kit_10x  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...  Multiome-RNA  Multiome-v1
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...  Multiome-RNA  Multiome-v1
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...  Multiome-RNA  Multiome-v1
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...  Multiome-RNA  Multiome-v1
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...  Multiome-RNA  Multiome-v1
#
#                                                    flushed scrublet_score  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...     yes       0.225806
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...     yes       0.136531
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...     yes       0.254438
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...     yes       0.289474
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...     yes       0.254438
#
#                                                     scrublet_leiden  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...              6,3
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...              6,3
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...              6,2
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...              7,0
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...              7,2
#
#                                                    cluster_scrublet_score  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...               0.254438
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...               0.254438
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...               0.254438
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...               0.225806
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...               0.213888
#
#                                                     doublet_pval  \
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...      0.000043
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...      0.000043
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...      0.000043
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...      0.000674
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...      0.001828
#
#                                                     doublet_bh_pval
# barcode
# HCAHeartST13146201_HCAHeartST13129134_GCAAACCGT...         0.000586
# HCAHeartST13146201_HCAHeartST13129134_ACAGCCGGT...         0.000586
# HCAHeartST13146201_HCAHeartST13129134_AGTGTGGCA...         0.000586
# HCAHeartST13146201_HCAHeartST13129134_CAAGTGAAG...         0.006062
# HCAHeartST13146201_HCAHeartST13129134_TGACTCCTC...         0.014099
#
# [5 rows x 21 columns]

# %%
adata.write('/nfs/team205/heart/anndata_objects/8regions/QC/multiome_RNA_adult_new-SAN-AVN_prefilter.h5ad')
# Out:
# ... storing 'sangerID' as categorical
# ... storing 'combinedID' as categorical
# ... storing 'donor' as categorical
# ... storing 'donor_type' as categorical
# ... storing 'region' as categorical
# ... storing 'region_finest' as categorical
# ... storing 'age' as categorical
# ... storing 'gender' as categorical
# ... storing 'facility' as categorical
# ... storing 'cell_or_nuclei' as categorical
# ... storing 'modality' as categorical
# ... storing 'kit_10x' as categorical
# ... storing 'flushed' as categorical
# ... storing 'scrublet_leiden' as categorical
# ... storing 'gene_name' as categorical
# ... storing 'feature_type' as categorical

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 146652 × 36601
#     obs: 'latent_RT_efficiency', 'latent_cell_probability', 'latent_scale', 'sangerID', 'combinedID', 'donor', 'donor_type', 'region', 'region_finest', 'age', 'gender', 'facility', 'cell_or_nuclei', 'modality', 'kit_10x', 'flushed', 'scrublet_score', 'scrublet_leiden', 'cluster_scrublet_score', 'doublet_pval', 'doublet_bh_pval'
#     var: 'gene_name', 'feature_type', 'ambient_expression-0', 'ambient_expression-1', 'ambient_expression-10', 'ambient_expression-11', 'ambient_expression-12', 'ambient_expression-13', 'ambient_expression-14', 'ambient_expression-15', 'ambient_expression-16', 'ambient_expression-2', 'ambient_expression-3', 'ambient_expression-4', 'ambient_expression-5', 'ambient_expression-6', 'ambient_expression-7', 'ambient_expression-8', 'ambient_expression-9'
#     obsm: 'latent_gene_encoding'

# %%
adata.obs['donor'].value_counts()
# Out:
# AH2     64903
# AV13    35489
# AV14    16809
# AV3     11985
# AV10     8847
# AH1      8619
# Name: donor, dtype: int64
